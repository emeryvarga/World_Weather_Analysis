# %%
# Import the dependencies.
import random
import numpy as np
import timeit
import pandas as pd
import matplotlib.pyplot as plt
import os
import time
from citipy import citipy
from datetime import datetime
from citipy import citipy
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
from scipy.stats import linregress

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size =2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module.
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 759

# %%
# Perform an API call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Retrieve the following information from the API call: Latitude and longitude, Maximum temperature,Percent humidity, Percent cloudiness, Wind speed, Weather description (for example, clouds, fog, light rain, clear sky)

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sobolevo
# Processing Record 2 of Set 1 | grand gaube
# Processing Record 3 of Set 1 | bluff
# Processing Record 4 of Set 1 | tuatapere
# Processing Record 5 of Set 1 | qui nhon
# Processing Record 6 of Set 1 | kodiak
# Processing Record 7 of Set 1 | carnarvon
# Processing Record 8 of Set 1 | comodoro rivadavia
# Processing Record 9 of Set 1 | port elizabeth
# Processing Record 10 of Set 1 | talara
# Processing Record 11 of Set 1 | hithadhoo
# Processing Record 12 of Set 1 | margate
# Processing Record 13 of Set 1 | norman wells
# Processing Record 14 of Set 1 | puerto leguizamo
# Processing Record 15 of Set 1 | upleta
# Processing Record 16 of Set 1 | maldonado
# Processing Record 17 of Set 1 | namanga
# Processing Record 18 of Set 1 | rantepao
# Processing Record 19 of Set 1 | hobart
# Processing Record 20 of Set 1 | kuytun
# Processing Record 21 of Set 1 | tasiilaq
# Processing Record 22 of Set 1 | prince rupert
# Processing Record 23 of Set 1 | portland
# Processing Record 24 of Set 1 | sherbakul
# Processing Record 25 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 1 | cape town
# Processing Record 27 of Set 1 | pevek
# Processing Record 28 of Set 1 | east london
# Processing Record 29 of Set 1 | lavrentiya
# Processing Record 30 of Set 1 | pudozh
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | san vicente
# Processing Record 33 of Set 1 | mount pleasant
# Processing Record 34 of Set 1 | vaini
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | saint-philippe
# Processing Record 37 of Set 1 | dikson
# Processing Record 38 of Set 1 | bredasdorp
# Processing Record 39 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 1 | spornoye
# Processing Record 42 of Set 1 | severo-kurilsk
# Processing Record 43 of Set 1 | grindavik
# Processing Record 44 of Set 1 | doha
# Processing Record 45 of Set 1 | rikitea
# Processing Record 46 of Set 1 | busselton
# Processing Record 47 of Set 1 | benghazi
# Processing Record 48 of Set 1 | henties bay
# Processing Record 49 of Set 1 | lujan
# Processing Record 50 of Set 1 | asfi
# Processing Record 1 of Set 2 | hilo
# Processing Record 2 of Set 2 | luderitz
# Processing Record 3 of Set 2 | lasa
# Processing Record 4 of Set 2 | clyde river
# Processing Record 5 of Set 2 | yarmouth
# Processing Record 6 of Set 2 | georgetown
# Processing Record 7 of Set 2 | ribeira grande
# Processing Record 8 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 2 | souillac
# Processing Record 10 of Set 2 | sete lagoas
# Processing Record 11 of Set 2 | kapaa
# Processing Record 12 of Set 2 | road town
# Processing Record 13 of Set 2 | chokurdakh
# Processing Record 14 of Set 2 | touros
# Processing Record 15 of Set 2 | persianovskiy
# Processing Record 16 of Set 2 | avarua
# Processing Record 17 of Set 2 | new norfolk
# Processing Record 18 of Set 2 | aden
# Processing Record 19 of Set 2 | tuktoyaktuk
# Processing Record 20 of Set 2 | paamiut
# Processing Record 21 of Set 2 | punta arenas
# Processing Record 22 of Set 2 | bambous virieux
# Processing Record 23 of Set 2 | tura
# Processing Record 24 of Set 2 | mareeba
# Processing Record 25 of Set 2 | albany
# Processing Record 26 of Set 2 | cherskiy
# Processing Record 27 of Set 2 | havoysund
# Processing Record 28 of Set 2 | butaritari
# Processing Record 29 of Set 2 | kavieng
# Processing Record 30 of Set 2 | bengkulu
# Processing Record 31 of Set 2 | bom jesus
# Processing Record 32 of Set 2 | bathsheba
# Processing Record 33 of Set 2 | shirakawa
# Processing Record 34 of Set 2 | amapa
# Processing Record 35 of Set 2 | vila franca do campo
# Processing Record 36 of Set 2 | cabo san lucas
# Processing Record 37 of Set 2 | mahebourg
# Processing Record 38 of Set 2 | ardabil
# Processing Record 39 of Set 2 | villarrica
# Processing Record 40 of Set 2 | neiafu
# Processing Record 41 of Set 2 | chuy
# Processing Record 42 of Set 2 | torbay
# Processing Record 43 of Set 2 | atambua
# Processing Record 44 of Set 2 | raton
# Processing Record 45 of Set 2 | ponta do sol
# Processing Record 46 of Set 2 | castro
# Processing Record 47 of Set 2 | kandrian
# Processing Record 48 of Set 2 | nokaneng
# Processing Record 49 of Set 2 | surt
# Processing Record 50 of Set 2 | esperance
# Processing Record 1 of Set 3 | malinyi
# Processing Record 2 of Set 3 | antalaha
# Processing Record 3 of Set 3 | ponta delgada
# Processing Record 4 of Set 3 | dire
# Processing Record 5 of Set 3 | thompson
# Processing Record 6 of Set 3 | svetlogorsk
# Processing Record 7 of Set 3 | tres arroyos
# Processing Record 8 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 3 | ahuimanu
# Processing Record 11 of Set 3 | kruisfontein
# Processing Record 12 of Set 3 | dryden
# Processing Record 13 of Set 3 | saskylakh
# Processing Record 14 of Set 3 | bowen
# Processing Record 15 of Set 3 | karratha
# Processing Record 16 of Set 3 | kautokeino
# Processing Record 17 of Set 3 | ucluelet
# Processing Record 18 of Set 3 | taoudenni
# Processing Record 19 of Set 3 | hamilton
# Processing Record 20 of Set 3 | booue
# Processing Record 21 of Set 3 | port alfred
# Processing Record 22 of Set 3 | jamestown
# Processing Record 23 of Set 3 | san patricio
# Processing Record 24 of Set 3 | qaanaaq
# Processing Record 25 of Set 3 | lebu
# Processing Record 26 of Set 3 | torbat-e jam
# Processing Record 27 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 3 | puerto ayora
# Processing Record 29 of Set 3 | ponta pora
# Processing Record 30 of Set 3 | panjab
# Processing Record 31 of Set 3 | tucuman
# Processing Record 32 of Set 3 | nikolskoye
# Processing Record 33 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 3 | nanyamba
# Processing Record 35 of Set 3 | tidore
# City not found. Skipping...
# Processing Record 36 of Set 3 | provost
# Processing Record 37 of Set 3 | saldanha
# Processing Record 38 of Set 3 | mvuma
# Processing Record 39 of Set 3 | faya
# Processing Record 40 of Set 3 | port blair
# Processing Record 41 of Set 3 | yellowknife
# Processing Record 42 of Set 3 | anchorage
# Processing Record 43 of Set 3 | tsabong
# Processing Record 44 of Set 3 | cracaoani
# City not found. Skipping...
# Processing Record 45 of Set 3 | ilulissat
# Processing Record 46 of Set 3 | meulaboh
# Processing Record 47 of Set 3 | linhares
# Processing Record 48 of Set 3 | antofagasta
# Processing Record 49 of Set 3 | cayenne
# Processing Record 50 of Set 3 | sinnamary
# Processing Record 1 of Set 4 | bilma
# Processing Record 2 of Set 4 | lakselv
# Processing Record 3 of Set 4 | rawson
# Processing Record 4 of Set 4 | mezen
# Processing Record 5 of Set 4 | nemuro
# Processing Record 6 of Set 4 | tambul
# City not found. Skipping...
# Processing Record 7 of Set 4 | hermanus
# Processing Record 8 of Set 4 | kattivakkam
# Processing Record 9 of Set 4 | atuona
# Processing Record 10 of Set 4 | arraial do cabo
# Processing Record 11 of Set 4 | pedro carbo
# Processing Record 12 of Set 4 | fortuna
# Processing Record 13 of Set 4 | buraydah
# Processing Record 14 of Set 4 | mgandu
# Processing Record 15 of Set 4 | tiznit
# Processing Record 16 of Set 4 | moree
# Processing Record 17 of Set 4 | mamallapuram
# Processing Record 18 of Set 4 | ahipara
# Processing Record 19 of Set 4 | airai
# Processing Record 20 of Set 4 | nara
# Processing Record 21 of Set 4 | abakaliki
# Processing Record 22 of Set 4 | iqaluit
# Processing Record 23 of Set 4 | date
# Processing Record 24 of Set 4 | salalah
# Processing Record 25 of Set 4 | batagay
# Processing Record 26 of Set 4 | paso de carrasco
# Processing Record 27 of Set 4 | farmington
# Processing Record 28 of Set 4 | laurens
# Processing Record 29 of Set 4 | sale
# Processing Record 30 of Set 4 | sal rei
# Processing Record 31 of Set 4 | valparaiso
# Processing Record 32 of Set 4 | longyearbyen
# Processing Record 33 of Set 4 | quang ngai
# Processing Record 34 of Set 4 | honningsvag
# Processing Record 35 of Set 4 | zongolica
# Processing Record 36 of Set 4 | mtwara
# Processing Record 37 of Set 4 | faanui
# Processing Record 38 of Set 4 | adrar
# Processing Record 39 of Set 4 | upernavik
# Processing Record 40 of Set 4 | barrow
# Processing Record 41 of Set 4 | viedma
# Processing Record 42 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 4 | lebanon
# Processing Record 44 of Set 4 | tuggurt
# City not found. Skipping...
# Processing Record 45 of Set 4 | arlit
# Processing Record 46 of Set 4 | coquimbo
# Processing Record 47 of Set 4 | sakakah
# Processing Record 48 of Set 4 | alakurtti
# Processing Record 49 of Set 4 | shebunino
# Processing Record 50 of Set 4 | kloulklubed
# Processing Record 1 of Set 5 | yumen
# Processing Record 2 of Set 5 | nanortalik
# Processing Record 3 of Set 5 | dunedin
# Processing Record 4 of Set 5 | provideniya
# Processing Record 5 of Set 5 | sarandi
# Processing Record 6 of Set 5 | buchanan
# Processing Record 7 of Set 5 | ouahigouya
# Processing Record 8 of Set 5 | beringovskiy
# Processing Record 9 of Set 5 | amahai
# Processing Record 10 of Set 5 | kariba
# Processing Record 11 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 12 of Set 5 | gazojak
# Processing Record 13 of Set 5 | bolobo
# Processing Record 14 of Set 5 | katsuura
# Processing Record 15 of Set 5 | tsuruoka
# Processing Record 16 of Set 5 | barra patuca
# Processing Record 17 of Set 5 | labuhan
# Processing Record 18 of Set 5 | kamenka
# Processing Record 19 of Set 5 | kostomuksha
# Processing Record 20 of Set 5 | bandarbeyla
# Processing Record 21 of Set 5 | praia
# Processing Record 22 of Set 5 | tias
# Processing Record 23 of Set 5 | bom jardim
# Processing Record 24 of Set 5 | dinsor
# City not found. Skipping...
# Processing Record 25 of Set 5 | geraldton
# Processing Record 26 of Set 5 | pedasi
# Processing Record 27 of Set 5 | khatanga
# Processing Record 28 of Set 5 | pinawa
# Processing Record 29 of Set 5 | simao
# Processing Record 30 of Set 5 | pacific grove
# Processing Record 31 of Set 5 | borovskoy
# Processing Record 32 of Set 5 | bossembele
# City not found. Skipping...
# Processing Record 33 of Set 5 | abalak
# Processing Record 34 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 5 | washington
# Processing Record 36 of Set 5 | dimataling
# Processing Record 37 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 38 of Set 5 | ngunguru
# Processing Record 39 of Set 5 | sandy bay
# Processing Record 40 of Set 5 | slave lake
# Processing Record 41 of Set 5 | pallisa
# Processing Record 42 of Set 5 | shibarghan
# City not found. Skipping...
# Processing Record 43 of Set 5 | nurobod
# Processing Record 44 of Set 5 | anadyr
# Processing Record 45 of Set 5 | klaksvik
# Processing Record 46 of Set 5 | lakes entrance
# Processing Record 47 of Set 5 | port lincoln
# Processing Record 48 of Set 5 | sao joao da barra
# Processing Record 49 of Set 5 | cravo norte
# Processing Record 50 of Set 5 | tiksi
# Processing Record 1 of Set 6 | hanzhong
# Processing Record 2 of Set 6 | sao filipe
# Processing Record 3 of Set 6 | zimovniki
# Processing Record 4 of Set 6 | lorengau
# Processing Record 5 of Set 6 | ostrovnoy
# Processing Record 6 of Set 6 | kieta
# Processing Record 7 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 8 of Set 6 | aksarayskiy
# Processing Record 9 of Set 6 | gorontalo
# Processing Record 10 of Set 6 | huarmey
# Processing Record 11 of Set 6 | portoferraio
# Processing Record 12 of Set 6 | panzhihua
# Processing Record 13 of Set 6 | vardo
# Processing Record 14 of Set 6 | batemans bay
# Processing Record 15 of Set 6 | gimli
# Processing Record 16 of Set 6 | pelym
# Processing Record 17 of Set 6 | egvekinot
# Processing Record 18 of Set 6 | bethel
# Processing Record 19 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 20 of Set 6 | harrisonburg
# Processing Record 21 of Set 6 | gigmoto
# Processing Record 22 of Set 6 | awbari
# Processing Record 23 of Set 6 | magadan
# Processing Record 24 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 6 | russell
# Processing Record 26 of Set 6 | kangaatsiaq
# Processing Record 27 of Set 6 | kombissiri
# Processing Record 28 of Set 6 | port moresby
# Processing Record 29 of Set 6 | malinovoye ozero
# Processing Record 30 of Set 6 | gloversville
# Processing Record 31 of Set 6 | qaqortoq
# Processing Record 32 of Set 6 | san lawrenz
# Processing Record 33 of Set 6 | terra santa
# Processing Record 34 of Set 6 | santa maria
# Processing Record 35 of Set 6 | dubbo
# Processing Record 36 of Set 6 | virginia beach
# Processing Record 37 of Set 6 | port-gentil
# Processing Record 38 of Set 6 | zhangye
# Processing Record 39 of Set 6 | korla
# Processing Record 40 of Set 6 | mar del plata
# Processing Record 41 of Set 6 | vestmannaeyjar
# Processing Record 42 of Set 6 | malangali
# Processing Record 43 of Set 6 | pitimbu
# Processing Record 44 of Set 6 | mao
# Processing Record 45 of Set 6 | fairbanks
# Processing Record 46 of Set 6 | leh
# Processing Record 47 of Set 6 | sucua
# Processing Record 48 of Set 6 | cockburn town
# Processing Record 49 of Set 6 | ormara
# Processing Record 50 of Set 6 | puerto baquerizo moreno
# Processing Record 1 of Set 7 | yeppoon
# Processing Record 2 of Set 7 | armidale
# Processing Record 3 of Set 7 | lieksa
# Processing Record 4 of Set 7 | aykhal
# Processing Record 5 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 6 of Set 7 | general roca
# Processing Record 7 of Set 7 | vasai
# Processing Record 8 of Set 7 | asau
# Processing Record 9 of Set 7 | outjo
# Processing Record 10 of Set 7 | deputatskiy
# Processing Record 11 of Set 7 | miri
# Processing Record 12 of Set 7 | soyo
# Processing Record 13 of Set 7 | divnomorskoye
# Processing Record 14 of Set 7 | lagoa
# Processing Record 15 of Set 7 | kondinskoye
# Processing Record 16 of Set 7 | sladkovo
# Processing Record 17 of Set 7 | codrington
# Processing Record 18 of Set 7 | vinces
# Processing Record 19 of Set 7 | soe
# Processing Record 20 of Set 7 | juegang
# Processing Record 21 of Set 7 | namatanai
# Processing Record 22 of Set 7 | ribas do rio pardo
# Processing Record 23 of Set 7 | san cristobal
# Processing Record 24 of Set 7 | tawkar
# City not found. Skipping...
# Processing Record 25 of Set 7 | hami
# Processing Record 26 of Set 7 | kapoeta
# Processing Record 27 of Set 7 | yar-sale
# Processing Record 28 of Set 7 | elko
# Processing Record 29 of Set 7 | briancon
# Processing Record 30 of Set 7 | coihaique
# Processing Record 31 of Set 7 | pisco
# Processing Record 32 of Set 7 | mersing
# Processing Record 33 of Set 7 | sirfa
# City not found. Skipping...
# Processing Record 34 of Set 7 | saint-augustin
# Processing Record 35 of Set 7 | oistins
# Processing Record 36 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 37 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 7 | pangnirtung
# Processing Record 39 of Set 7 | alenquer
# Processing Record 40 of Set 7 | dombovar
# Processing Record 41 of Set 7 | rabo de peixe
# Processing Record 42 of Set 7 | mukhen
# Processing Record 43 of Set 7 | jutai
# Processing Record 44 of Set 7 | tilichiki
# Processing Record 45 of Set 7 | matara
# Processing Record 46 of Set 7 | manakara
# Processing Record 47 of Set 7 | nador
# Processing Record 48 of Set 7 | bull savanna
# Processing Record 49 of Set 7 | shchelyayur
# City not found. Skipping...
# Processing Record 50 of Set 7 | tautira
# Processing Record 1 of Set 8 | sanmenxia
# Processing Record 2 of Set 8 | sola
# Processing Record 3 of Set 8 | maxixe
# Processing Record 4 of Set 8 | mardin
# Processing Record 5 of Set 8 | macaboboni
# City not found. Skipping...
# Processing Record 6 of Set 8 | camana
# Processing Record 7 of Set 8 | dandong
# Processing Record 8 of Set 8 | puro
# Processing Record 9 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 10 of Set 8 | llanes
# Processing Record 11 of Set 8 | neuquen
# Processing Record 12 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 8 | san-pedro
# Processing Record 14 of Set 8 | sioux lookout
# Processing Record 15 of Set 8 | kutum
# Processing Record 16 of Set 8 | mehamn
# Processing Record 17 of Set 8 | harper
# Processing Record 18 of Set 8 | kingman
# Processing Record 19 of Set 8 | along
# Processing Record 20 of Set 8 | rehoboth
# Processing Record 21 of Set 8 | sorland
# Processing Record 22 of Set 8 | saint-georges
# Processing Record 23 of Set 8 | hirara
# Processing Record 24 of Set 8 | candolim
# Processing Record 25 of Set 8 | samarai
# Processing Record 26 of Set 8 | tezu
# Processing Record 27 of Set 8 | mana
# Processing Record 28 of Set 8 | a
# City not found. Skipping...
# Processing Record 29 of Set 8 | waitara
# Processing Record 30 of Set 8 | nortelandia
# Processing Record 31 of Set 8 | zhoucheng
# Processing Record 32 of Set 8 | beyneu
# Processing Record 33 of Set 8 | ulladulla
# Processing Record 34 of Set 8 | fevralsk
# City not found. Skipping...
# Processing Record 35 of Set 8 | manali
# Processing Record 36 of Set 8 | jijiga
# Processing Record 37 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 38 of Set 8 | alice springs
# Processing Record 39 of Set 8 | snyder
# Processing Record 40 of Set 8 | sept-iles
# Processing Record 41 of Set 8 | goure
# Processing Record 42 of Set 8 | san quintin
# Processing Record 43 of Set 8 | marv dasht
# City not found. Skipping...
# Processing Record 44 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 8 | terenos
# Processing Record 46 of Set 8 | komsomolskiy
# Processing Record 47 of Set 8 | copiapo
# Processing Record 48 of Set 8 | laguna
# Processing Record 49 of Set 8 | mahadday weyne
# City not found. Skipping...
# Processing Record 50 of Set 8 | palana
# Processing Record 1 of Set 9 | dzialdowo
# Processing Record 2 of Set 9 | semey
# Processing Record 3 of Set 9 | aiquile
# Processing Record 4 of Set 9 | malanje
# Processing Record 5 of Set 9 | mocambique
# City not found. Skipping...
# Processing Record 6 of Set 9 | srednekolymsk
# Processing Record 7 of Set 9 | ndola
# Processing Record 8 of Set 9 | betanzos
# Processing Record 9 of Set 9 | kavaratti
# Processing Record 10 of Set 9 | sitka
# Processing Record 11 of Set 9 | merauke
# Processing Record 12 of Set 9 | noumea
# Processing Record 13 of Set 9 | jahrom
# City not found. Skipping...
# Processing Record 14 of Set 9 | port hawkesbury
# Processing Record 15 of Set 9 | bougouni
# Processing Record 16 of Set 9 | dali
# Processing Record 17 of Set 9 | garowe
# Processing Record 18 of Set 9 | axim
# Processing Record 19 of Set 9 | burdur
# Processing Record 20 of Set 9 | nhulunbuy
# Processing Record 21 of Set 9 | orje
# Processing Record 22 of Set 9 | glenwood springs
# Processing Record 23 of Set 9 | milkovo
# Processing Record 24 of Set 9 | luanda
# Processing Record 25 of Set 9 | tomatlan
# Processing Record 26 of Set 9 | spas-demensk
# Processing Record 27 of Set 9 | bima
# Processing Record 28 of Set 9 | tabou
# Processing Record 29 of Set 9 | kulhudhuffushi
# Processing Record 30 of Set 9 | barra dos coqueiros
# Processing Record 31 of Set 9 | kropotkin
# Processing Record 32 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 9 | dukat
# Processing Record 34 of Set 9 | college
# Processing Record 35 of Set 9 | florianopolis
# Processing Record 36 of Set 9 | avera
# Processing Record 37 of Set 9 | bucerias
# Processing Record 38 of Set 9 | praia da vitoria
# Processing Record 39 of Set 9 | yichang
# Processing Record 40 of Set 9 | nouakchott
# Processing Record 41 of Set 9 | mayumba
# Processing Record 42 of Set 9 | dolores
# Processing Record 43 of Set 9 | yorosso
# Processing Record 44 of Set 9 | husavik
# Processing Record 45 of Set 9 | libreville
# Processing Record 46 of Set 9 | san policarpo
# Processing Record 47 of Set 9 | leshukonskoye
# Processing Record 48 of Set 9 | kununurra
# Processing Record 49 of Set 9 | jiuquan
# Processing Record 50 of Set 9 | dalby
# Processing Record 1 of Set 10 | alice town
# Processing Record 2 of Set 10 | daigo
# Processing Record 3 of Set 10 | ancud
# Processing Record 4 of Set 10 | ambilobe
# Processing Record 5 of Set 10 | saint-leu
# Processing Record 6 of Set 10 | purpe
# Processing Record 7 of Set 10 | vilhena
# Processing Record 8 of Set 10 | ekhabi
# Processing Record 9 of Set 10 | vostok
# Processing Record 10 of Set 10 | elbistan
# Processing Record 11 of Set 10 | dekar
# Processing Record 12 of Set 10 | tadine
# Processing Record 13 of Set 10 | damietta
# Processing Record 14 of Set 10 | warrnambool
# Processing Record 15 of Set 10 | ust-tsilma
# Processing Record 16 of Set 10 | naryan-mar
# Processing Record 17 of Set 10 | ambatofinandrahana
# Processing Record 18 of Set 10 | policarpa
# Processing Record 19 of Set 10 | ewa beach
# Processing Record 20 of Set 10 | kambove
# Processing Record 21 of Set 10 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 22 of Set 10 | busia
# Processing Record 23 of Set 10 | yenagoa
# Processing Record 24 of Set 10 | sur
# Processing Record 25 of Set 10 | tucuma
# Processing Record 26 of Set 10 | port arthur
# Processing Record 27 of Set 10 | rio grande
# Processing Record 28 of Set 10 | narsaq
# Processing Record 29 of Set 10 | tawnat
# City not found. Skipping...
# Processing Record 30 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 31 of Set 10 | beira
# Processing Record 32 of Set 10 | jambi
# Processing Record 33 of Set 10 | skagastrond
# City not found. Skipping...
# Processing Record 34 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 35 of Set 10 | sebezh
# Processing Record 36 of Set 10 | la rochelle
# Processing Record 37 of Set 10 | mbanza-ngungu
# Processing Record 38 of Set 10 | ayagoz
# Processing Record 39 of Set 10 | el mahalla el kubra
# City not found. Skipping...
# Processing Record 40 of Set 10 | natal
# Processing Record 41 of Set 10 | kaitangata
# Processing Record 42 of Set 10 | liverpool
# Processing Record 43 of Set 10 | shache
# Processing Record 44 of Set 10 | mujiayingzi
# Processing Record 45 of Set 10 | sol-iletsk
# Processing Record 46 of Set 10 | ust-maya
# Processing Record 47 of Set 10 | cidreira
# Processing Record 48 of Set 10 | kholtoson
# Processing Record 49 of Set 10 | salinas
# Processing Record 50 of Set 10 | erenhot
# Processing Record 1 of Set 11 | saint george
# Processing Record 2 of Set 11 | ostrov
# Processing Record 3 of Set 11 | acapulco
# Processing Record 4 of Set 11 | diffa
# Processing Record 5 of Set 11 | ginir
# Processing Record 6 of Set 11 | berlevag
# Processing Record 7 of Set 11 | anaconda
# Processing Record 8 of Set 11 | tanabe
# Processing Record 9 of Set 11 | malpe
# Processing Record 10 of Set 11 | chengde
# Processing Record 11 of Set 11 | comarapa
# Processing Record 12 of Set 11 | katobu
# Processing Record 13 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 11 | lerwick
# Processing Record 15 of Set 11 | mihail kogalniceanu
# Processing Record 16 of Set 11 | leopold
# Processing Record 17 of Set 11 | huilong
# Processing Record 18 of Set 11 | misratah
# Processing Record 19 of Set 11 | kaliua
# Processing Record 20 of Set 11 | aklavik
# Processing Record 21 of Set 11 | arman
# Processing Record 22 of Set 11 | caravelas
# Processing Record 23 of Set 11 | abu dhabi
# Processing Record 24 of Set 11 | novyy svit
# Processing Record 25 of Set 11 | homer
# Processing Record 26 of Set 11 | tall kayf
# Processing Record 27 of Set 11 | muriwai beach
# Processing Record 28 of Set 11 | pecos
# Processing Record 29 of Set 11 | sechura
# Processing Record 30 of Set 11 | altay
# Processing Record 31 of Set 11 | manzhouli
# Processing Record 32 of Set 11 | santa cruz de la palma
# Processing Record 33 of Set 11 | dingle
# Processing Record 34 of Set 11 | maniitsoq
# Processing Record 35 of Set 11 | deep river
# Processing Record 36 of Set 11 | banda aceh
# Processing Record 37 of Set 11 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 11 | taltal
# Processing Record 39 of Set 11 | krasnooktyabrskiy
# Processing Record 40 of Set 11 | pasni
# Processing Record 41 of Set 11 | hovd
# Processing Record 42 of Set 11 | chippewa falls
# Processing Record 43 of Set 11 | okha
# Processing Record 44 of Set 11 | donskoye
# Processing Record 45 of Set 11 | nantucket
# Processing Record 46 of Set 11 | abilene
# Processing Record 47 of Set 11 | saint-pierre
# Processing Record 48 of Set 11 | laguna de perlas
# Processing Record 49 of Set 11 | margherita
# Processing Record 50 of Set 11 | qeshm
# Processing Record 1 of Set 12 | hondo
# Processing Record 2 of Set 12 | zhuhai
# Processing Record 3 of Set 12 | krasnogorskiy
# Processing Record 4 of Set 12 | tingrela
# City not found. Skipping...
# Processing Record 5 of Set 12 | sistranda
# Processing Record 6 of Set 12 | lima
# Processing Record 7 of Set 12 | vuktyl
# Processing Record 8 of Set 12 | ushtobe
# Processing Record 9 of Set 12 | ouallam
# Processing Record 10 of Set 12 | starkville
# Processing Record 11 of Set 12 | clinton
# Processing Record 12 of Set 12 | kabanjahe
# Processing Record 13 of Set 12 | barcelos
# Processing Record 14 of Set 12 | paracuru
# Processing Record 15 of Set 12 | omboue
# Processing Record 16 of Set 12 | sercaia
# Processing Record 17 of Set 12 | kikwit
# Processing Record 18 of Set 12 | tocopilla
# Processing Record 19 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 20 of Set 12 | namibe
# Processing Record 21 of Set 12 | zyryanka
# Processing Record 22 of Set 12 | linxia
# Processing Record 23 of Set 12 | manokwari
# Processing Record 24 of Set 12 | okhotsk
# Processing Record 25 of Set 12 | batagay-alyta
# Processing Record 26 of Set 12 | ust-karsk
# Processing Record 27 of Set 12 | kaeo
# Processing Record 28 of Set 12 | kisangani
# Processing Record 29 of Set 12 | bayji
# Processing Record 30 of Set 12 | orbetello
# Processing Record 31 of Set 12 | gao
# Processing Record 32 of Set 12 | victoria
# Processing Record 33 of Set 12 | ilhabela
# Processing Record 34 of Set 12 | bregovo
# Processing Record 35 of Set 12 | qianan
# Processing Record 36 of Set 12 | sydney
# Processing Record 37 of Set 12 | teguise
# Processing Record 38 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 39 of Set 12 | kiunga
# Processing Record 40 of Set 12 | ndele
# Processing Record 41 of Set 12 | peace river
# Processing Record 42 of Set 12 | chinhoyi
# Processing Record 43 of Set 12 | odweyne
# Processing Record 44 of Set 12 | pousat
# City not found. Skipping...
# Processing Record 45 of Set 12 | awjilah
# Processing Record 46 of Set 12 | broken hill
# Processing Record 47 of Set 12 | coari
# Processing Record 48 of Set 12 | riohacha
# Processing Record 49 of Set 12 | lady frere
# Processing Record 50 of Set 12 | mogadishu
# Processing Record 1 of Set 13 | bonito
# Processing Record 2 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 3 of Set 13 | dagana
# Processing Record 4 of Set 13 | two hills
# Processing Record 5 of Set 13 | kupang
# Processing Record 6 of Set 13 | senica
# Processing Record 7 of Set 13 | old road
# City not found. Skipping...
# Processing Record 8 of Set 13 | tubuala
# Processing Record 9 of Set 13 | bubaque
# Processing Record 10 of Set 13 | wlodawa
# Processing Record 11 of Set 13 | los llanos de aridane
# Processing Record 12 of Set 13 | hasaki
# Processing Record 13 of Set 13 | carutapera
# Processing Record 14 of Set 13 | fare
# Processing Record 15 of Set 13 | amparafaravola
# Processing Record 16 of Set 13 | myingyan
# Processing Record 17 of Set 13 | nome
# Processing Record 18 of Set 13 | ust-omchug
# Processing Record 19 of Set 13 | wencheng
# Processing Record 20 of Set 13 | orangeburg
# Processing Record 21 of Set 13 | twin falls
# Processing Record 22 of Set 13 | siutu
# City not found. Skipping...
# Processing Record 23 of Set 13 | mtinko
# Processing Record 24 of Set 13 | panalingaan
# Processing Record 25 of Set 13 | hofn
# Processing Record 26 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 13 | los andes
# Processing Record 28 of Set 13 | volokonovka
# Processing Record 29 of Set 13 | rumonge
# Processing Record 30 of Set 13 | dakar
# Processing Record 31 of Set 13 | uvat
# Processing Record 32 of Set 13 | nelson bay
# Processing Record 33 of Set 13 | vao
# Processing Record 34 of Set 13 | bismarck
# Processing Record 35 of Set 13 | rocha
# Processing Record 36 of Set 13 | nyimba
# Processing Record 37 of Set 13 | rexburg
# Processing Record 38 of Set 13 | solnechnyy
# Processing Record 39 of Set 13 | umtata
# Processing Record 40 of Set 13 | anito
# Processing Record 41 of Set 13 | qasigiannguit
# Processing Record 42 of Set 13 | te anau
# Processing Record 43 of Set 13 | inta
# Processing Record 44 of Set 13 | yatou
# Processing Record 45 of Set 13 | akdepe
# Processing Record 46 of Set 13 | virden
# Processing Record 47 of Set 13 | puerto escondido
# Processing Record 48 of Set 13 | yunjinghong
# City not found. Skipping...
# Processing Record 49 of Set 13 | salym
# Processing Record 50 of Set 13 | kishtwar
# Processing Record 1 of Set 14 | port hedland
# Processing Record 2 of Set 14 | aswan
# Processing Record 3 of Set 14 | tual
# Processing Record 4 of Set 14 | la paz centro
# Processing Record 5 of Set 14 | clyde
# Processing Record 6 of Set 14 | rybinsk
# Processing Record 7 of Set 14 | sumenep
# Processing Record 8 of Set 14 | teguldet
# Processing Record 9 of Set 14 | forrest city
# Processing Record 10 of Set 14 | geresk
# City not found. Skipping...
# Processing Record 11 of Set 14 | medea
# Processing Record 12 of Set 14 | mount isa
# Processing Record 13 of Set 14 | manono
# Processing Record 14 of Set 14 | acari
# Processing Record 15 of Set 14 | trairi
# Processing Record 16 of Set 14 | san julian
# Processing Record 17 of Set 14 | port shepstone
# Processing Record 18 of Set 14 | kamaishi
# Processing Record 19 of Set 14 | sao pedro do sul
# Processing Record 20 of Set 14 | kindu
# Processing Record 21 of Set 14 | biak
# Processing Record 22 of Set 14 | kahului
# Processing Record 23 of Set 14 | yulara
# Processing Record 24 of Set 14 | campos
# Processing Record 25 of Set 14 | leningradskiy
# Processing Record 26 of Set 14 | mentougou
# Processing Record 27 of Set 14 | champerico
# Processing Record 28 of Set 14 | tessalit
# Processing Record 29 of Set 14 | szeghalom
# Processing Record 30 of Set 14 | azuaga
# Processing Record 31 of Set 14 | sisimiut
# Processing Record 32 of Set 14 | oktyabrskiy
# Processing Record 33 of Set 14 | dothan
# Processing Record 34 of Set 14 | constitucion
# Processing Record 35 of Set 14 | la ronge
# Processing Record 36 of Set 14 | ipu
# Processing Record 37 of Set 14 | the valley
# Processing Record 38 of Set 14 | solotcha
# Processing Record 39 of Set 14 | malmesbury
# Processing Record 40 of Set 14 | carberry
# Processing Record 41 of Set 14 | christchurch
# Processing Record 42 of Set 14 | trezzo
# City not found. Skipping...
# Processing Record 43 of Set 14 | kismayo
# Processing Record 44 of Set 14 | maridi
# Processing Record 45 of Set 14 | decatur
# Processing Record 46 of Set 14 | uwayl
# City not found. Skipping...
# Processing Record 47 of Set 14 | roma
# Processing Record 48 of Set 14 | ozinki
# Processing Record 49 of Set 14 | golyshmanovo
# Processing Record 50 of Set 14 | guerrero negro
# Processing Record 1 of Set 15 | sapa
# Processing Record 2 of Set 15 | talnakh
# Processing Record 3 of Set 15 | zhigansk
# Processing Record 4 of Set 15 | tuskegee
# Processing Record 5 of Set 15 | oranjestad
# Processing Record 6 of Set 15 | shelburne
# Processing Record 7 of Set 15 | angoche
# Processing Record 8 of Set 15 | moron
# Processing Record 9 of Set 15 | inongo
# Processing Record 10 of Set 15 | port macquarie
# Processing Record 11 of Set 15 | serik
# Processing Record 12 of Set 15 | acarau
# Processing Record 13 of Set 15 | mayo
# Processing Record 14 of Set 15 | lompoc
# Processing Record 15 of Set 15 | salihli
# Processing Record 16 of Set 15 | boa vista
# Processing Record 17 of Set 15 | havre-saint-pierre
# Processing Record 18 of Set 15 | oyonnax
# Processing Record 19 of Set 15 | xuddur
# Processing Record 20 of Set 15 | hranice
# Processing Record 21 of Set 15 | belsand
# Processing Record 22 of Set 15 | humberto de campos
# Processing Record 23 of Set 15 | handwara
# City not found. Skipping...
# Processing Record 24 of Set 15 | salina
# Processing Record 25 of Set 15 | cabedelo
# Processing Record 26 of Set 15 | barranca
# Processing Record 27 of Set 15 | rock sound
# Processing Record 28 of Set 15 | magistralnyy
# Processing Record 29 of Set 15 | medicine hat
# Processing Record 30 of Set 15 | scottsburgh
# City not found. Skipping...
# Processing Record 31 of Set 15 | fort nelson
# Processing Record 32 of Set 15 | carballo
# Processing Record 33 of Set 15 | irkutsk
# Processing Record 34 of Set 15 | buala
# Processing Record 35 of Set 15 | isangel
# Processing Record 36 of Set 15 | litoral del san juan
# City not found. Skipping...
# Processing Record 37 of Set 15 | talcahuano
# Processing Record 38 of Set 15 | aras
# Processing Record 39 of Set 15 | mirpur bathoro
# City not found. Skipping...
# Processing Record 40 of Set 15 | bure
# Processing Record 41 of Set 15 | mangan
# Processing Record 42 of Set 15 | sorong
# Processing Record 43 of Set 15 | siva
# Processing Record 44 of Set 15 | paungde
# Processing Record 45 of Set 15 | rossosh
# Processing Record 46 of Set 15 | vaitape
# Processing Record 47 of Set 15 | denpasar
# Processing Record 48 of Set 15 | juneau
# Processing Record 49 of Set 15 | beidao
# Processing Record 50 of Set 15 | beloha
# Processing Record 1 of Set 16 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 16 | ornskoldsvik
# Processing Record 3 of Set 16 | raduzhnyy
# Processing Record 4 of Set 16 | panguna
# Processing Record 5 of Set 16 | darab
# Processing Record 6 of Set 16 | tuy hoa
# Processing Record 7 of Set 16 | preobrazheniye
# Processing Record 8 of Set 16 | umm durman
# City not found. Skipping...
# Processing Record 9 of Set 16 | deloraine
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Sobolevo      RU  54.4299   31.8996     23.86        78
# 1         Grand Gaube      MU -20.0064   57.6608     73.38        75
# 2               Bluff      NZ -46.6000  168.3333     55.60        68
# 3           Tuatapere      NZ -46.1333  167.6833     58.30        60
# 4            Qui Nhon      VN  13.7667  109.2333     78.03        86
# 5              Kodiak      US  57.7900 -152.4072     18.91        49
# 6           Carnarvon      AU -24.8667  113.6333     78.87        36
# 7  Comodoro Rivadavia      AR -45.8667  -67.5000     53.46        37
# 8      Port Elizabeth      ZA -33.9180   25.5701     62.89        88
# 9              Talara      PE  -4.5772  -81.2719     65.25        84
#
#    Cloudiness  Wind Speed Current Description
# 0         100        3.85     overcast clouds
# 1           0        5.99           clear sky
# 2          45       12.28    scattered clouds
# 3          53        7.49       broken clouds
# 4          96       17.67          light rain
# 5           1       11.50           clear sky
# 6           0       13.80           clear sky
# 7           0        8.05           clear sky
# 8          90       13.80     overcast clouds
# 9          42        7.90    scattered clouds

# %%
# Export the DataFrame as WeatherPy_Database.csv into the Weather_Database folder
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
